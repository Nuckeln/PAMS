# %% [markdown]
# #  <center> <u>Übung:</u> Pandas Renaming & Combining

# %% [markdown]
# ### 1) (L) Importiere `Pandas` und lade den Datensatz von `uebung/cars.csv` und lass dir den `Kopf` ausgeben

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./uebung/cars.csv', index_col=0)
df.head()
# Out:
#                                  car_id          marke   modell     preis  \
# 0  2f3fc81f-8794-4182-89b6-844ba36cb764     Volkswagen     Golf   9.797 €
# 1  e52e54ee-db7f-4c06-9acc-5a83cb5b3803     Volkswagen     Golf  13.890 €
# 2  3f88ed87-b01e-4467-bbb9-6abb1f15db32  Mercedes-Benz  SLK 300  19.990 €
# 3  3e326228-97ae-4890-b3ba-a8a2ae6bd414  Mercedes-Benz  SLK 350  19.990 €
# 4  e4ab245f-e604-4a24-84ae-4ccdde25410a  Mercedes-Benz    A 220  17.450 €
#
#     kilometer erstzulassung         kraftstoffart        getriebe  \
# 0   79.449 km       04/2011                Benzin  Schaltgetriebe
# 1   76.486 km       01/2015  Benzin, E10-geeignet  Schaltgetriebe
# 2   84.000 km       07/2009                Benzin       Automatik
# 3   84.000 km       07/2009                Benzin       Automatik
# 4  109.252 km       12/2012                Diesel       Automatik
#
#           leistung    hubraum       hu      plz             farbe  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### 2) (L) Ändere den Spaltennamen `leistung` zu `kw_ps`

# %%
df = df.rename(columns={'leistung': 'kw_ps'})

# %%
df.head(2)
# Out:
#                                  car_id       marke modell     preis  \
# 0  2f3fc81f-8794-4182-89b6-844ba36cb764  Volkswagen   Golf   9.797 €
# 1  e52e54ee-db7f-4c06-9acc-5a83cb5b3803  Volkswagen   Golf  13.890 €
#
#    kilometer erstzulassung         kraftstoffart        getriebe  \
# 0  79.449 km       04/2011                Benzin  Schaltgetriebe
# 1  76.486 km       01/2015  Benzin, E10-geeignet  Schaltgetriebe
#
#             kw_ps    hubraum   hu      plz             farbe  \
# 0   63 kW (86 PS)  1.197 cm³  Neu   4720.0              Weiß
# 1  92 kW (125 PS)  1.395 cm³  Neu  13088.0  Schwarz Metallic
#
#    anzahlderFahrzeughalter  kategorie  anzahlSitzplaetze anzahlderTueren  \
# 0                      NaN  Limousine                5.0             4/5
# 1                      2.0  Limousine                5.0             4/5
#
#   schadstoffklasse umweltplakette          klimatisierung    innenausstattung  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### 3) (L) Erstelle dir zwei `DataFrames`. Das erste `DataFrame` mit dem Name `df1` besteht aus den ersten 100 Zeilen des ursprünglichen `DataFrames df`. Das zweite namens `df2` aus den Zeilen 100-200.

# %%
df1 = df[:100]

# %%
df1.shape
# Out:
# (100, 22)

# %%
df2 = df[100:200]

# %%
df2.shape
# Out:
# (100, 22)

# %% [markdown]
# ***

# %% [markdown]
# ### 4) (M) Verbinde nun die beiden `DataFrames` `df1` und `df2` miteinander. Beim resultierenden `DataFrame` namens `df_conc` soll zuerst das `df2` erscheinend und anschleißend das `df1`. Der Index des resultierenden `DataFrames df_conc` soll bei 0 beginnen und bis zum Ende aufsteigend nummeriert sein.
# #### Verwende nicht die `.append` Methode

# %%
df_conc = pd.concat([df2, df1], 
                    axis=0,
                    ignore_index=True)

# %%
df_conc
# Out:
#                                    car_id          marke       modell  \
# 0    acf573ae-8bf7-48c2-9d1f-6d987afb95d2     Volkswagen       Beetle
# 1    3b8b35d8-2d37-47bf-b691-cd8715720bde  Mercedes-Benz      GLK 250
# 2    94bbe4da-d5d3-4c32-8215-feaf5b85cd20  Mercedes-Benz        S 500
# 3    3df9e4db-298b-4e7e-b924-5f1a904144de     Volkswagen       Tiguan
# 4    7e85e2a6-2b77-41a5-a7cb-7f806e847233     Volkswagen         Golf
# ..                                    ...            ...          ...
# 195  2c49e482-d66f-4e33-a51c-d372a2020072     Volkswagen         Golf
# 196  7ce8e006-17bb-4be7-9f72-4e5312cb0a44  Mercedes-Benz      CLA 250
# 197  27954d5c-1c70-408c-a1cf-7dffebda3bce     Volkswagen  T6 Multivan
# 198  93ddc1e4-aaa2-4a2c-9ac4-10959bb20af0     Volkswagen         Golf
# 199  ae870268-8246-4d2c-838e-cfd5429ff600            BMW          428
#
#         preis   kilometer erstzulassung         kraftstoffart        getriebe  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### 5) (M) In dieser Aufgabe bereiten wir den Datensatz für Aufgabe 6 vor. Die Vorbereitung beeinhaltet unterschiedlichstes Wissen von dem was du bereits gelernt hast

# %% [markdown]
# #### 1) Aufteilung der Daten in zwei `DataFrames`. Einmal `df_cars` welches `car_id`, `marke` und `modell` beinhaltet und einmal `df_car_details` welches `car_id`, `preis` und `kilometer` des `DataFrames` `df_conc` beinhaltet

# %%
df_cars = df_conc[['car_id', 'marke', 'modell']]
df_cars
# Out:
#                                    car_id          marke       modell
# 0    acf573ae-8bf7-48c2-9d1f-6d987afb95d2     Volkswagen       Beetle
# 1    3b8b35d8-2d37-47bf-b691-cd8715720bde  Mercedes-Benz      GLK 250
# 2    94bbe4da-d5d3-4c32-8215-feaf5b85cd20  Mercedes-Benz        S 500
# 3    3df9e4db-298b-4e7e-b924-5f1a904144de     Volkswagen       Tiguan
# 4    7e85e2a6-2b77-41a5-a7cb-7f806e847233     Volkswagen         Golf
# ..                                    ...            ...          ...
# 195  2c49e482-d66f-4e33-a51c-d372a2020072     Volkswagen         Golf
# 196  7ce8e006-17bb-4be7-9f72-4e5312cb0a44  Mercedes-Benz      CLA 250
# 197  27954d5c-1c70-408c-a1cf-7dffebda3bce     Volkswagen  T6 Multivan
# 198  93ddc1e4-aaa2-4a2c-9ac4-10959bb20af0     Volkswagen         Golf
# 199  ae870268-8246-4d2c-838e-cfd5429ff600            BMW          428
#
# [200 rows x 3 columns]

# %%
df_car_details = df_conc[['car_id', 'preis', 'kilometer']]
df_car_details
# Out:
#                                    car_id     preis   kilometer
# 0    acf573ae-8bf7-48c2-9d1f-6d987afb95d2   9.890 €  119.699 km
# 1    3b8b35d8-2d37-47bf-b691-cd8715720bde  16.998 €   60.000 km
# 2    94bbe4da-d5d3-4c32-8215-feaf5b85cd20  29.870 €   69.500 km
# 3    3df9e4db-298b-4e7e-b924-5f1a904144de  24.390 €  114.112 km
# 4    7e85e2a6-2b77-41a5-a7cb-7f806e847233  19.900 €   96.000 km
# ..                                    ...       ...         ...
# 195  2c49e482-d66f-4e33-a51c-d372a2020072   6.999 €   89.893 km
# 196  7ce8e006-17bb-4be7-9f72-4e5312cb0a44  24.900 €   69.705 km
# 197  27954d5c-1c70-408c-a1cf-7dffebda3bce  72.990 €   10.146 km
# 198  93ddc1e4-aaa2-4a2c-9ac4-10959bb20af0  17.750 €   73.200 km
# 199  ae870268-8246-4d2c-838e-cfd5429ff600  24.900 €   59.082 km
#
# [200 rows x 3 columns]

# %% [markdown]
# #### 2) Mische beide `DataFrames` mit der `.sample(frac=1)` Funktion

# %%
df_cars = df_cars.sample(frac=1)
df_cars.head()
# Out:
#                                    car_id          marke    modell
# 94   5004b61e-bebb-4a9a-9e2b-09e129e770b4  Mercedes-Benz     E 200
# 134  8a287aaa-e794-4377-b35f-c948ab5a2a95           Jeep  Wrangler
# 146  cfe81641-bd89-4ea1-9c84-f774a926d75d  Mercedes-Benz      Vito
# 150  dad83a90-e26d-45e3-b54e-bfd5b34ebbf3            BMW       420
# 85   74861af9-4200-4e36-b86a-67cf64525f0f  Mercedes-Benz     A 250

# %%
df_car_details = df_car_details.sample(frac=1)
df_car_details.head()
# Out:
#                                    car_id     preis   kilometer
# 174  bf1ae6b6-e6b6-45ab-86de-f14ae1cf79e5  12.890 €  124.091 km
# 55   ff183002-bec1-4471-84bd-5136829c7519   9.750 €   84.000 km
# 25   a788cb5e-cbf5-4364-a413-15e87d61899d  28.490 €  104.050 km
# 145  2aa59eaf-dd51-487f-af76-06898c85559c  11.933 €   97.250 km
# 6    07cc6a8d-4988-4605-a6ea-8bbc932866d1  12.999 €  126.000 km

# %% [markdown]
# #### 3) Kürze `df_car_details`, indem lediglich die ersten 73 Zeilen in dem `DataFrame` genommen werden

# %%
df_car_details = df_car_details[:73]

# %%
df_car_details.shape
# Out:
# (73, 3)

# %% [markdown]
# ***

# %% [markdown]
# ### 6) (S) Szenario:
# #### Aktuell benutzt unsere Marketingabteilung eine Datei namens `df_cars` welche lediglich Daten zum Auto beinhaltet wie Marke und Modell. Die Abteilung Einkauf benutzt eine andere Datei (`df_car_details`)um Preise unterschiedlicher Autos zu vergleichen, wobei hier lediglich die KM Anzahl eine Rolle spielt. Um genauere Analysen machen zu können, müssen wir die beiden `DataFrames` miteinander kombinieren. Die Gemeinsamkeit beider `DataFrames` ist die Spalte `car_id`. Diese beinhaltet immer einen genauen Identifizierungsschlüssel und symbolisiert in jedem der beiden `DataFrames` ein und das selbe Auto. Deine Aufgabe ist es einen Weg zu finden, die beiden `DataFrames` miteiander zu verbinden um ein großes `DataFrame` namens `df_joined` zu erhalten. Beachte, dass das `DataFrame` `df_car_details` beschädigt wurde und nicht mehr über alle Zeilen verfügt.

# %%
df_joined = df_cars.join(df_car_details.set_index('car_id'), on="car_id")

# %%
df_joined
# Out:
#                                    car_id          marke    modell     preis  \
# 94   5004b61e-bebb-4a9a-9e2b-09e129e770b4  Mercedes-Benz     E 200       NaN
# 134  8a287aaa-e794-4377-b35f-c948ab5a2a95           Jeep  Wrangler       NaN
# 146  cfe81641-bd89-4ea1-9c84-f774a926d75d  Mercedes-Benz      Vito       NaN
# 150  dad83a90-e26d-45e3-b54e-bfd5b34ebbf3            BMW       420  22.490 €
# 85   74861af9-4200-4e36-b86a-67cf64525f0f  Mercedes-Benz     A 250       NaN
# ..                                    ...            ...       ...       ...
# 54   42203489-4af3-42f4-a5a1-1294fbbd9a3e     Volkswagen    Touran       NaN
# 82   db3c1394-6e1c-41a3-8768-69b9916cc03e            BMW       220  24.880 €
# 190  ecdad2d4-6572-4a4e-8a00-7a1273ab4bd7            NaN       NaN       NaN
# 142  d0a1f7c6-f50c-41bc-8f86-0062d56b48be     Volkswagen    Touran       NaN
# 125  1cd2f253-91d3-4d2d-82aa-50c19daec81a           Audi        A6       NaN
#
#       kilometer
# 94          NaN
# ...

# %% [markdown]
# ### 7) (L) Sortier den Index aufsteigend und vergleiche das `DataFrame` `df_joined` mit dem erstellten `DataFrame` `df_conc`. Wähle beim `df_conc` lediglich die Spalten `car_id`, `marke`, `modell`, `preis` und `kilometer` aus.

# %%
df_joined.sort_index()
# Out:
#                                    car_id          marke       modell  \
# 0    acf573ae-8bf7-48c2-9d1f-6d987afb95d2     Volkswagen       Beetle
# 1    3b8b35d8-2d37-47bf-b691-cd8715720bde  Mercedes-Benz      GLK 250
# 2    94bbe4da-d5d3-4c32-8215-feaf5b85cd20  Mercedes-Benz        S 500
# 3    3df9e4db-298b-4e7e-b924-5f1a904144de     Volkswagen       Tiguan
# 4    7e85e2a6-2b77-41a5-a7cb-7f806e847233     Volkswagen         Golf
# ..                                    ...            ...          ...
# 195  2c49e482-d66f-4e33-a51c-d372a2020072     Volkswagen         Golf
# 196  7ce8e006-17bb-4be7-9f72-4e5312cb0a44  Mercedes-Benz      CLA 250
# 197  27954d5c-1c70-408c-a1cf-7dffebda3bce     Volkswagen  T6 Multivan
# 198  93ddc1e4-aaa2-4a2c-9ac4-10959bb20af0     Volkswagen         Golf
# 199  ae870268-8246-4d2c-838e-cfd5429ff600            BMW          428
#
#         preis  kilometer
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# ...

# %%
df_conc[['car_id', 'marke', 'modell', 'preis', 'kilometer']]
# Out:
#                                    car_id          marke       modell  \
# 0    acf573ae-8bf7-48c2-9d1f-6d987afb95d2     Volkswagen       Beetle
# 1    3b8b35d8-2d37-47bf-b691-cd8715720bde  Mercedes-Benz      GLK 250
# 2    94bbe4da-d5d3-4c32-8215-feaf5b85cd20  Mercedes-Benz        S 500
# 3    3df9e4db-298b-4e7e-b924-5f1a904144de     Volkswagen       Tiguan
# 4    7e85e2a6-2b77-41a5-a7cb-7f806e847233     Volkswagen         Golf
# ..                                    ...            ...          ...
# 195  2c49e482-d66f-4e33-a51c-d372a2020072     Volkswagen         Golf
# 196  7ce8e006-17bb-4be7-9f72-4e5312cb0a44  Mercedes-Benz      CLA 250
# 197  27954d5c-1c70-408c-a1cf-7dffebda3bce     Volkswagen  T6 Multivan
# 198  93ddc1e4-aaa2-4a2c-9ac4-10959bb20af0     Volkswagen         Golf
# 199  ae870268-8246-4d2c-838e-cfd5429ff600            BMW          428
#
#         preis   kilometer
# 0     9.890 €  119.699 km
# 1    16.998 €   60.000 km
# 2    29.870 €   69.500 km
# ...
