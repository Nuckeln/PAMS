# %%
#pd.concat([df1[~df1.index.isin(df2.index)], df2])
import pandas as pd
import numpy as np

df1 = pd.read_excel('teil1.xlsx')
df2 = pd.read_excel('teil2.xlsx')
df1.set_index('Transfer Order Number', inplace=True)
df2.set_index('Transfer Order Number', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 2
#       1 #pd.concat([df1[~df1.index.isin(df2.index)], df2])
# ----> 2 import pandas as pd
#       3 import numpy as np
#       5 df1 = pd.read_excel('teil1.xlsx')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df1 = pd.concat([df1[~df1.index.isin(df2.index)], df2])

# %% [markdown]
# Hi Martin,
#
# anbei schon mal die Credentials fürs Reporting, dann kannst Du versuchen, eine DB-Verbindung zu machen:
#
# Server name: batsql-pd-ne-cmes-dev-10.database.windows.net
# Datenbankname: batsdb-pd-ne-dev-reporting_SuperDepot
# Benutzer: batedp-cmes-dev-reportinguser
# Passwort: b2.5v^H!IKjetuXMVNvW
#
# Bei Zugriffsproblemen neue FW-Regel, Details für user unter
# http://speedtest.zscaler.com/perf
# verfügbar
#
# Bitte beachte, dass der CopyJob noch nicht fertig ist und daher keine Tabellen / whatever verfügbar sind.
#
# Die Verbindung kannst Du auch damit prüfen:
# https://learn.microsoft.com/en-us/sql/azure-data-studio/download-azure-data-studio?view=sql-server-ver16

# %%
# import pyodbc as db
# server = 'batsql-pd-ne-cmes-dev-10.database.windows.net.database.windows.net'
# database = 'batsdb-pd-ne-dev-reporting_SuperDepot'
# username = 'batedp-cmes-dev-reportinguser'
# password = '{b2.5v^H!IKjetuXMVNvW}'   
# driver= '{ODBC Driver 17 for SQL Server}'

# with db.connect('DRIVER='+driver+';SERVER=tcp:'+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password) as conn:
#     with conn.cursor() as cursor:
#         cursor.execute("SELECT TOP 3 name, collation_name FROM sys.databases")
#         row = cursor.fetchone()
#         while row:
#             print (str(row[0]) + " " + str(row[1]))
#             row = cursor.fetchone()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 import pyodbc as db
#       2 server = 'batsql-pd-ne-cmes-dev-10.database.windows.net.database.windows.net'
#       3 database = 'batsdb-pd-ne-dev-reporting_SuperDepot'
#
# ImportError: dlopen(/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pyodbc.cpython-310-darwin.so, 0x0002): symbol not found in flat namespace '_SQLAllocHandle'
