# %%
import streamlit as st
import streamlit_authenticator as stauth
from pathlib import Path
from SQL import datenLadenUser, updateUser
import pandas as pd

names =  ["Martin",  "Norbert", 'MichaelK','Markus', 'MichaelP','Sabrina']
usernames = ["martin", "norbert", "michaelk", "markus", "michaelp", "sabrina"]
password = ["Bruno24-", "schlangenleder","unterfluhrschleppkettenfördersystem",'Bayern1' ,'naIhrSpacken','SuperDepot2022']
function = ["admin", "user", "user", "user", "user",'user']
rechte = [1,2,3,4,5,1]


hasched_passwords = stauth.Hasher(password).generate()


#add to df
df = pd.DataFrame({'name':names, 'username':usernames, 'password':hasched_passwords, 'function':function, 'rechte':rechte})
updateUser(df)

# %%
from SQL import datenLadenUser, updateUser
df = datenLadenUser()
usernames = df['username'].tolist()
names = df['name'].tolist()
passwords = df['password'].tolist()

credentials = {"usernames":{}}
        
for uname,name,pwd in zip(usernames,names,passwords):
    user_dict = {"name": name, "password": pwd}
    credentials["usernames"].update({uname: user_dict})

df
# Out:
#        name  username                                           password  \
# 0    Martin    martin  $2b$12$ZSvSuP5lEfvpwsVPAqHCI.Wviso9vlN.DhGdepi...
# 1   Norbert   norbert  $2b$12$9Xx4dZ4U1gI2UPsg0tLppeUfUb4w8Bbr/dxpWId...
# 2  MichaelK  michaelk  $2b$12$9hr7DkhiSDKwRBCsHyL2KOndS8JMqJB003t7cU/...
# 3    Markus    markus  $2b$12$z8gonNOIVmQvR5AlEBpunug2C3DJFhV0NJrT7c1...
# 4  MichaelP  michaelp  $2b$12$9lvEB.Vtu2nOcGRhlv6VzuE.1YwQJPeKqnuFXwN...
# 5   Sabrina   sabrina  $2b$12$XqdDTtGxMqXbg0NlPE4DjOXLJyDhuUtZzYdFwZJ...
#
#   function  rechte
# 0    admin       1
# 1     user       2
# 2     user       3
# 3     user       4
# 4     user       5
# 5     user       1
