# %%
import streamlit as st
import streamlit_authenticator as stauth
from pathlib import Path
from SQL import datenLadenUser, updateUser
import pandas as pd

names =  ["Martin",  "Norbert", 'MichaelK','Markus', 'MichaelP']
usernames = ["martin", "norbert", "michaelk", "markus", "michaelp"]
password = ["Bruno24-", "schlangenleder","unterfluhrschleppkettenfördersystem",'Bayern1' ,'naIhrSpacken']
function = ["admin", "user", "user", "user", "user"]
rechte = [1,2,3,4,5]


hasched_passwords = stauth.Hasher(password).generate()


#add to df
df = pd.DataFrame({'name':names, 'username':usernames, 'password':hasched_passwords, 'function':function, 'rechte':rechte})
updateUser(df)

# %%
from SQL import datenLadenUser, updateUser
df = datenLadenUser()
usernames = df['username'].tolist()
names = df['name'].tolist()
passwords = df['password'].tolist()

credentials = {"usernames":{}}
        
for uname,name,pwd in zip(usernames,names,passwords):
    user_dict = {"name": name, "password": pwd}
    credentials["usernames"].update({uname: user_dict})

df
# Out:
#        name  username                                           password  \
# 0    Martin    martin  $2b$12$Gp/SC8TLhQMa4bhO4RtfAeeBN..itt0yCcBxIxP...
# 1   Norbert   norbert  $2b$12$MASV9O6Al/fau.RuUupfvesXFosS0mqW5tILLbM...
# 2  MichaelK  michaelk  $2b$12$2s5rO3bHD3U7QD3/yipq9OBtdX1vGHjc29MLtS0...
# 3    Markus    markus  $2b$12$7kCFbCUbkyRC7TRjFrUXB.tUXOMeKcNa4/TO3h5...
# 4  MichaelP  michaelp  $2b$12$knBDEoXBcYS.8nMkvmhrkuuNWfwtWH3.qO3xC5O...
#
#   function  rechte
# 0    admin       1
# 1     user       2
# 2     user       3
# 3     user       4
# 4     user       5
